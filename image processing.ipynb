# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('ms dhoni.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (580, 1170, 3)

# %%
print(img)
# Out:
# [[[127 151 156]
#   [127 151 156]
#   [128 152 158]
#   ...
#   [121 150 156]
#   [120 148 157]
#   [120 148 157]]
#
#  [[127 151 156]
#   [127 151 156]
#   [128 152 158]
#   ...
#   [121 150 156]
#   [120 148 157]
#   [120 148 157]]
#
#  [[128 152 158]
#   [128 152 158]
#   [128 152 158]
#   ...
#   [121 150 156]
#   [120 148 157]
#   [120 148 157]]
#
#  ...
#
#  [[128 187   8]
#   [128 187   8]
#   [127 186   7]
#   ...
#   [138 192  17]
#   [138 192  19]
#   [141 194  21]]
#
#  [[132 191   9]
#   [132 191   9]
#   [131 190   8]
#   ...
#   [142 195  20]
#   [140 193  18]
#   [138 192  17]]
#
#  [[134 194  10]
#   [133 192   8]
#   [132 191   7]
#   ...
#   [143 197  21]
#   [142 195  20]
#   [141 194  19]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('ms dhoni.jpg')
img_resized = img.resize((250,150))

# %%
img_resized.save('resized_dhoni.jpg')

# %%
img_res = mpimg.imread('resized_dhoni.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (150, 250, 3)

# %%
import cv2

# %%
img = cv2.imread('ms dhoni.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (580, 1170, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (580, 1170)

# %%
from PIL import Image
from IPython.display import display, clear_output

# convert color from CV2 BGR back to RGB
image = cv2.cvtColor(grayscale_image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=1170x580>

# %%
cv2.imwrite('grayscale_image.jpg', grayscale_image)
# Out:
# True
